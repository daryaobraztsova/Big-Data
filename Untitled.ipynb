# %% [markdown]
# # Таблица

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import desc, asc
import pyspark.sql.functions as f
from pyspark.sql.functions import lower
from pyspark.sql.functions import abs
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import col,isnan, when, count
spark = SparkSession.builder.appName("Introduction to Spark").getOrCreate()
df_pyspark = spark.read.csv("/mnt/c/Users/data.csv", header = True, inferSchema = True)
df_pyspark.show(5)
# Out:
# +--------+------------------+---------+---------+------------+----------------+----------------+------+-----------+----+------------------+--------------------+
# |children|     days_employed|dob_years|education|education_id|   family_status|family_status_id|gender|income_type|debt|      total_income|             purpose|
# +--------+------------------+---------+---------+------------+----------------+----------------+------+-----------+----+------------------+--------------------+
# |       1|-8437.673027760233|       42|   высшее|           0| женат / замужем|               0|     F|  сотрудник|   0| 253875.6394525987|       покупка жилья|
# |       1|-4024.803753850451|       36|  среднее|           1| женат / замужем|               0|     F|  сотрудник|   0|112080.01410244203|приобретение авто...|
# |       0|-5623.422610230956|       33|  Среднее|           1| женат / замужем|               0|     M|  сотрудник|   0|145885.95229686378|       покупка жилья|
# |       3|-4124.747206540018|       32|  среднее|           1| женат / замужем|               0|     M|  сотрудник|   0| 267628.5503294142|дополнительное об...|
# |       0|340266.07204682194|       53|  среднее|           1|гражданский брак|               1|     F|  пенсионер|   0|158616.07787006293|     сыграть свадьбу|
# +--------+------------------+---------+---------+------------+----------------+----------------+------+-----------+----+------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# # Поиск столбцов с пропусками

# %%
df_pyspark.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_pyspark.columns]).show()
# Out:
# +--------+-------------+---------+---------+------------+-------------+----------------+------+-----------+----+------------+-------+
# |children|days_employed|dob_years|education|education_id|family_status|family_status_id|gender|income_type|debt|total_income|purpose|
# +--------+-------------+---------+---------+------------+-------------+----------------+------+-----------+----+------------+-------+
# |       0|         2174|        0|        0|           0|            0|               0|     0|          0|   0|        2174|      0|
# +--------+-------------+---------+---------+------------+-------------+----------------+------+-----------+----+------------+-------+

# %%
print(df_pyspark.count())
# Out:
# 21525

# %% [markdown]
# # Какую долю составляют пропущенные значения в каждом из столбцов с пропусками?

# %%
print((2174/21525*100))
# Out:
# 10.099883855981417

# %% [markdown]
# # Делаем значения целочисленными

# %%
df_pyspark = df_pyspark.withColumn('total_income', df_pyspark['total_income'].cast(IntegerType()))

# %%
df_pyspark.show(5)
# Out:
# +--------+------------------+---------+---------+------------+----------------+----------------+------+-----------+----+------------+--------------------+
# |children|     days_employed|dob_years|education|education_id|   family_status|family_status_id|gender|income_type|debt|total_income|             purpose|
# +--------+------------------+---------+---------+------------+----------------+----------------+------+-----------+----+------------+--------------------+
# |       1|-8437.673027760233|       42|   высшее|           0| женат / замужем|               0|     F|  сотрудник|   0|      253875|       покупка жилья|
# |       1|-4024.803753850451|       36|  среднее|           1| женат / замужем|               0|     F|  сотрудник|   0|      112080|приобретение авто...|
# |       0|-5623.422610230956|       33|  Среднее|           1| женат / замужем|               0|     M|  сотрудник|   0|      145885|       покупка жилья|
# |       3|-4124.747206540018|       32|  среднее|           1| женат / замужем|               0|     M|  сотрудник|   0|      267628|дополнительное об...|
# |       0|340266.07204682194|       53|  среднее|           1|гражданский брак|               1|     F|  пенсионер|   0|      158616|     сыграть свадьбу|
# +--------+------------------+---------+---------+------------+----------------+----------------+------+-----------+----+------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# # Заполняем пропуски медианным значением:

# %%
df_pyspark=df_pyspark.fillna(df_pyspark.select(f.mean(df_pyspark['total_income'])).collect()[0][0])

# %% [markdown]
# # Положительные значения days_employed

# %%
df_pyspark = df_pyspark.withColumn('days_employed', df_pyspark['days_employed'].cast(IntegerType()))
df_pyspark = df_pyspark.withColumn('days_employed', abs(df_pyspark.days_employed)).show()
# Out:
# +--------+-------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+
# |children|days_employed|dob_years|          education|education_id|       family_status|family_status_id|gender|income_type|debt|      total_income|             purpose|
# +--------+-------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+
# |       2|         5718|       39|            Среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 83892.81598726273|покупка жилья для...|
# |       0|         5229|       43|             ВЫСШЕЕ|           0|Не женат / не зам...|               4|     F|  сотрудник|   0|203279.59982532426|строительство жил...|
# |       0|        63046|       66|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0|63046.497661473615|   операции с жильем|
# |       0|       384733|       56|            среднее|           1|      вдовец / вдова|               2|     F|  пенсионер|   0|162416.13776348685|на покупку своего...|
# |       0|         2470|       60|             высшее|           0|     женат / замужем|               0|     M|  компаньон|   0| 402898.7745922168|сделка с подержан...|
# |       0|        63046|       53|            среднее|           1|           в разводе|               3|     F|  сотрудник|   0|63046.497661473615|        ремонт жилью|
# |       1|        63046|       21|            среднее|           1|    гражданский брак|               1|     F|  сотрудник|   0|63046.497661473615|             свадьба|
# |       0|         2406|       49|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   0| 409301.2063069334|дополнительное об...|
# |       0|         2451|       28|             высшее|           0|Не женат / не зам...|               4|     F|  компаньон|   0|222058.18216149238|операции со своей...|
# |       0|         1022|       45|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 197924.8501360915|получение образов...|
# |       0|        10017|       55|            среднее|           1|     женат / замужем|               0|     F|госслужащий|   0|144175.82313369436|строительство соб...|
# |       1|         3470|       49|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 272974.2514086593|операции с коммер...|
# |       0|         1449|       40|            среднее|           1|           в разводе|               3|     F|  сотрудник|   0|103974.92723365672|        ремонт жилью|
# |       1|         2223|       39|            среднее|           1|     женат / замужем|               0|     M|  компаньон|   0| 234912.3689592191|строительство соб...|
# |       1|         2536|       45|             ВЫСШЕЕ|           0|     женат / замужем|               0|     F|  компаньон|   1|347011.39233836177|заняться образова...|
# |       0|         1172|       24|неоконченное высшее|           2|     женат / замужем|               0|     M|  компаньон|   0| 268534.9178821679|на покупку подерж...|
# |       0|         4462|       40|            среднее|           1|     женат / замужем|               0|     F|  сотрудник|   0| 73888.34869012855|строительство нед...|
# |       0|       370534|       66|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0| 143508.3143341441|покупка жилья для...|
# |       2|         2068|       35|            среднее|           1|    гражданский брак|               1|     F|  компаньон|   0| 320285.7900125033|сделка с автомобилем|
# |       0|         1381|       44|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   1|118668.89538388044|       покупка жилья|
# +--------+-------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Медианные значения в days_employed

# %%
df_pyspark=df_pyspark.fillna(df_pyspark.select(f.mean(df_pyspark['days_employed'])).collect()[0][0])

# %% [markdown]
# # Приведение к нижнему регистру

# %%
df_pyspark = df_pyspark.withColumn("education", lower(df_pyspark["education"]))
df_pyspark.show(20)
# Out:
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+
# |children|      days_employed|dob_years|          education|education_id|       family_status|family_status_id|gender|income_type|debt|      total_income|             purpose|
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+
# |       2|  -5718.70890108714|       39|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 83892.81598726273|покупка жилья для...|
# |       0|  -5229.55206892918|       43|             высшее|           0|Не женат / не зам...|               4|     F|  сотрудник|   0|203279.59982532426|строительство жил...|
# |       0| 384733.81603224203|       56|            среднее|           1|      вдовец / вдова|               2|     F|  пенсионер|   0|162416.13776348685|на покупку своего...|
# |       0| -2470.912765901067|       60|             высшее|           0|     женат / замужем|               0|     M|  компаньон|   0| 402898.7745922168|сделка с подержан...|
# |       0| -2406.218612832741|       49|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   0| 409301.2063069334|дополнительное об...|
# |       0| -2451.554606204293|       28|             высшее|           0|Не женат / не зам...|               4|     F|  компаньон|   0|222058.18216149238|операции со своей...|
# |       0|-1022.5242584869244|       45|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 197924.8501360915|получение образов...|
# |       0|-10017.272437304076|       55|            среднее|           1|     женат / замужем|               0|     F|госслужащий|   0|144175.82313369436|строительство соб...|
# |       1|-3470.1255595432594|       49|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 272974.2514086593|операции с коммер...|
# |       0| -1449.253158207052|       40|            среднее|           1|           в разводе|               3|     F|  сотрудник|   0|103974.92723365672|        ремонт жилью|
# |       1|  -2223.70292128767|       39|            среднее|           1|     женат / замужем|               0|     M|  компаньон|   0| 234912.3689592191|строительство соб...|
# |       1|-2536.2882113926944|       45|             высшее|           0|     женат / замужем|               0|     F|  компаньон|   1|347011.39233836177|заняться образова...|
# |       0|-1172.1886523429555|       24|неоконченное высшее|           2|     женат / замужем|               0|     M|  компаньон|   0| 268534.9178821679|на покупку подерж...|
# |       0|-4462.2513422632455|       40|            среднее|           1|     женат / замужем|               0|     F|  сотрудник|   0| 73888.34869012855|строительство нед...|
# |       0|  370534.5513057049|       66|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0| 143508.3143341441|покупка жилья для...|
# |       2|-2068.5332525034164|       35|            среднее|           1|    гражданский брак|               1|     F|  компаньон|   0| 320285.7900125033|сделка с автомобилем|
# |       0|-1381.3970873521887|       44|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   1|118668.89538388044|       покупка жилья|
# |       0| -5202.530538606559|       63|             высшее|           0|     женат / замужем|               0|     M|  компаньон|   0|451466.65005079407|  высшее образование|
# |       0| 381009.79450185376|       64|            среднее|           1|      вдовец / вдова|               2|     F|  пенсионер|   1|223827.77000417816|получение высшего...|
# |       0|-1752.9412035640523|       43|неоконченное высшее|           2|           в разводе|               3|     F|  сотрудник|   0| 269060.8874198726|покупка недвижимости|
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Удаление строк-дубликатов

# %%
df_pyspark = df_pyspark.distinct()

# %%
print(df_pyspark.count())
# Out:
# 21454

# %% [markdown]
# # Создание двух новых датафреймов

# %%
df_pyspark.createOrReplaceTempView('dubli')
new_education_df=spark.sql("select education, education_id from dubli group by education, education_id")
new_family_df=spark.sql("select family_status, family_status_id from dubli group by family_status, family_status_id")

new_education_df.show()
new_family_df.show()

df_pyspark.drop('education')
df_pyspark.drop('family_status')
# Out:
# +-------------------+------------+
# |          education|education_id|
# +-------------------+------------+
# |     ученая степень|           4|
# |             высшее|           0|
# |          начальное|           3|
# |неоконченное высшее|           2|
# |            среднее|           1|
# +-------------------+------------+
#
# +--------------------+----------------+
# |       family_status|family_status_id|
# +--------------------+----------------+
# |    гражданский брак|               1|
# |      вдовец / вдова|               2|
# |Не женат / не зам...|               4|
# |     женат / замужем|               0|
# |           в разводе|               3|
# +--------------------+----------------+
# DataFrame[children: int, days_employed: double, dob_years: int, education: string, education_id: int, family_status_id: int, gender: string, income_type: string, debt: int, total_income: double, purpose: string]

# %% [markdown]
# # На основании диапазонов, указанных ниже, создали столбец total_income_category с категориями:

# %%
from pyspark.sql.functions import udf 
def income_group(income): 
    if income <= 30000: 
        return "E"
    elif income <= 50000:
        return "D"
    elif income <= 200000:
        return "C"
    elif income <= 1000000:
        return "B"
    else: 
        return "A"

totalincome_group_udf = udf(income_group) 
df_pyspark = df_pyspark.withColumn("total_income_category", totalincome_group_udf(df_pyspark.total_income))

df_pyspark.show(20)
# Out:
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+---------------------+
# |children|      days_employed|dob_years|          education|education_id|       family_status|family_status_id|gender|income_type|debt|      total_income|             purpose|total_income_category|
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+---------------------+
# |       0| 384733.81603224203|       56|            среднее|           1|      вдовец / вдова|               2|     F|  пенсионер|   0|162416.13776348685|на покупку своего...|                    C|
# |       0|  393452.1445002313|       62|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0|173640.35088220533|строительство жил...|                    C|
# |       0| -2470.912765901067|       60|             высшее|           0|     женат / замужем|               0|     M|  компаньон|   0| 402898.7745922168|сделка с подержан...|                    B|
# |       0| -2406.218612832741|       49|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   0| 409301.2063069334|дополнительное об...|                    B|
# |       0| -2451.554606204293|       28|             высшее|           0|Не женат / не зам...|               4|     F|  компаньон|   0|222058.18216149238|операции со своей...|                    B|
# |       0|-1022.5242584869244|       45|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 197924.8501360915|получение образов...|                    C|
# |       0|-10017.272437304076|       55|            среднее|           1|     женат / замужем|               0|     F|госслужащий|   0|144175.82313369436|строительство соб...|                    C|
# |       1|-3470.1255595432594|       49|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 272974.2514086593|операции с коммер...|                    B|
# |       0| -1449.253158207052|       40|            среднее|           1|           в разводе|               3|     F|  сотрудник|   0|103974.92723365672|        ремонт жилью|                    C|
# |       1|  -2223.70292128767|       39|            среднее|           1|     женат / замужем|               0|     M|  компаньон|   0| 234912.3689592191|строительство соб...|                    B|
# |       0|-1172.1886523429555|       24|неоконченное высшее|           2|     женат / замужем|               0|     M|  компаньон|   0| 268534.9178821679|на покупку подерж...|                    B|
# |       0| -8123.205745904102|       51|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   0|263243.64089775673|на покупку своего...|                    B|
# |       0|-4462.2513422632455|       40|            среднее|           1|     женат / замужем|               0|     F|  сотрудник|   0| 73888.34869012855|строительство нед...|                    C|
# |       0| 397680.94855920796|       58|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0| 61139.91166074379|получение высшего...|                    C|
# |       0|  370534.5513057049|       66|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0| 143508.3143341441|покупка жилья для...|                    C|
# |       2|-2068.5332525034164|       35|            среднее|           1|    гражданский брак|               1|     F|  компаньон|   0| 320285.7900125033|сделка с автомобилем|                    B|
# |       0|-1381.3970873521887|       44|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   1|118668.89538388044|       покупка жилья|                    C|
# |       0| -5202.530538606559|       63|             высшее|           0|     женат / замужем|               0|     M|  компаньон|   0|451466.65005079407|  высшее образование|                    B|
# |       0| 381009.79450185376|       64|            среднее|           1|      вдовец / вдова|               2|     F|  пенсионер|   1|223827.77000417816|получение высшего...|                    B|
# |       0|-1752.9412035640523|       43|неоконченное высшее|           2|           в разводе|               3|     F|  сотрудник|   0| 269060.8874198726|покупка недвижимости|                    B|
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+---------------------+
# only showing top 20 rows

# %% [markdown]
# # Создали функцию, которая на основании данных из столбца purpose сформирует новый столбец purpose_category, в который войдут следующие категории

# %%
from pyspark.sql.functions import udf 
def purpose_group(purpose): 
    if 'автомобил' in purpose: 
        return "операции с автомобилем"
    elif 'жиль' in purpose or 'недвижимо' in purpose:
        return "операции с недвижимостью"
    elif 'свадь' in purpose:
        return "проведение свадьбы"
    else:
        return "получение образования"

purpose_group_udf = udf(purpose_group) 
df_pyspark = df_pyspark.withColumn("purpose_category", purpose_group_udf(df_pyspark.purpose))

df_pyspark.show()
# Out:
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+---------------------+--------------------+
# |children|      days_employed|dob_years|          education|education_id|       family_status|family_status_id|gender|income_type|debt|      total_income|             purpose|total_income_category|    purpose_category|
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+---------------------+--------------------+
# |       0| 384733.81603224203|       56|            среднее|           1|      вдовец / вдова|               2|     F|  пенсионер|   0|162416.13776348685|на покупку своего...|                    C|операции с автомо...|
# |       0|  393452.1445002313|       62|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0|173640.35088220533|строительство жил...|                    C|операции с недвиж...|
# |       0| -2470.912765901067|       60|             высшее|           0|     женат / замужем|               0|     M|  компаньон|   0| 402898.7745922168|сделка с подержан...|                    B|операции с автомо...|
# |       0| -2406.218612832741|       49|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   0| 409301.2063069334|дополнительное об...|                    B|получение образов...|
# |       0| -2451.554606204293|       28|             высшее|           0|Не женат / не зам...|               4|     F|  компаньон|   0|222058.18216149238|операции со своей...|                    B|операции с недвиж...|
# |       0|-1022.5242584869244|       45|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 197924.8501360915|получение образов...|                    C|получение образов...|
# |       0|-10017.272437304076|       55|            среднее|           1|     женат / замужем|               0|     F|госслужащий|   0|144175.82313369436|строительство соб...|                    C|операции с недвиж...|
# |       1|-3470.1255595432594|       49|            среднее|           1|     женат / замужем|               0|     M|  сотрудник|   0| 272974.2514086593|операции с коммер...|                    B|операции с недвиж...|
# |       0| -1449.253158207052|       40|            среднее|           1|           в разводе|               3|     F|  сотрудник|   0|103974.92723365672|        ремонт жилью|                    C|операции с недвиж...|
# |       1|  -2223.70292128767|       39|            среднее|           1|     женат / замужем|               0|     M|  компаньон|   0| 234912.3689592191|строительство соб...|                    B|операции с недвиж...|
# |       0|-1172.1886523429555|       24|неоконченное высшее|           2|     женат / замужем|               0|     M|  компаньон|   0| 268534.9178821679|на покупку подерж...|                    B|операции с автомо...|
# |       0| -8123.205745904102|       51|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   0|263243.64089775673|на покупку своего...|                    B|операции с автомо...|
# |       0|-4462.2513422632455|       40|            среднее|           1|     женат / замужем|               0|     F|  сотрудник|   0| 73888.34869012855|строительство нед...|                    C|операции с недвиж...|
# |       0| 397680.94855920796|       58|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0| 61139.91166074379|получение высшего...|                    C|получение образов...|
# |       0|  370534.5513057049|       66|            среднее|           1|     женат / замужем|               0|     F|  пенсионер|   0| 143508.3143341441|покупка жилья для...|                    C|операции с недвиж...|
# |       2|-2068.5332525034164|       35|            среднее|           1|    гражданский брак|               1|     F|  компаньон|   0| 320285.7900125033|сделка с автомобилем|                    B|операции с автомо...|
# |       0|-1381.3970873521887|       44|            среднее|           1|     женат / замужем|               0|     F|  компаньон|   1|118668.89538388044|       покупка жилья|                    C|операции с недвиж...|
# |       0| -5202.530538606559|       63|             высшее|           0|     женат / замужем|               0|     M|  компаньон|   0|451466.65005079407|  высшее образование|                    B|получение образов...|
# |       0| 381009.79450185376|       64|            среднее|           1|      вдовец / вдова|               2|     F|  пенсионер|   1|223827.77000417816|получение высшего...|                    B|получение образов...|
# |       0|-1752.9412035640523|       43|неоконченное высшее|           2|           в разводе|               3|     F|  сотрудник|   0| 269060.8874198726|покупка недвижимости|                    B|операции с недвиж...|
# +--------+-------------------+---------+-------------------+------------+--------------------+----------------+------+-----------+----+------------------+--------------------+---------------------+--------------------+
# only showing top 20 rows
